# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file_path = '/Users/bryanwenger/Desktop/Desktop_Master/Coding/github_projects/fantasy_football/Prep_Work/data_sets/2022_data.csv'

# %%
#Reading in file and removing Div/0 values. The CSV is a working file and will have these until the season is complete.  
data = pd.read_csv(file_path, na_values=['#VALUE!', '#DIV/0!'])

# %%
data.head()
# Out:
#              Player Position  Week 1  Week 2  Week 3  Week 4  Week 5  Week 6  \
# 0   Herbert, Justin       QB   23.26   23.46   12.58    21.1   14.42    8.42
# 1  Elliott, Ezekiel       RB    4.90    4.90   13.50     8.1    7.80   14.60
# 2  Mitchell, Elijah       RB    4.10     NaN     NaN     NaN     NaN     NaN
# 3     Diggs, Stefon       WR   18.20   32.80    7.40     6.2   16.20   20.80
# 4       Evans, Mike       WR   14.10    6.10     NaN    22.3    8.10    4.20
#
#    Week 7  Week 8  ...  Week 10  Week 11  Week 12  Week 13  Week 14  Rd 1  \
# 0   18.12     NaN  ...     12.4     18.7    28.76     18.1      NaN   NaN
# 1   17.70     NaN  ...      NaN     16.7    15.50     15.1      NaN   NaN
# 2     NaN     NaN  ...      NaN      NaN      NaN      NaN      NaN   NaN
# 3     NaN    16.8  ...     12.8     10.8    13.70     15.2      NaN   NaN
# 4    9.60    12.3  ...      5.4      NaN     3.10      5.9      NaN   NaN
#
#    Rd 2  Rd 3  Totals  Average
# ...

# %%
df = pd.DataFrame(data)

# %%
data13 = df.drop(['Week 14', 'Rd 1', 'Rd 2', 'Rd 3'], axis=1)

# %%
data13.head()
# Out:
#              Player Position  Week 1  Week 2  Week 3  Week 4  Week 5  Week 6  \
# 0   Herbert, Justin       QB   23.26   23.46   12.58    21.1   14.42    8.42
# 1  Elliott, Ezekiel       RB    4.90    4.90   13.50     8.1    7.80   14.60
# 2  Mitchell, Elijah       RB    4.10     NaN     NaN     NaN     NaN     NaN
# 3     Diggs, Stefon       WR   18.20   32.80    7.40     6.2   16.20   20.80
# 4       Evans, Mike       WR   14.10    6.10     NaN    22.3    8.10    4.20
#
#    Week 7  Week 8  Week 9  Week 10  Week 11  Week 12  Week 13  Totals  Average
# 0   18.12     NaN    12.1     12.4     18.7    28.76     18.1  211.42    17.62
# 1   17.70     NaN     NaN      NaN     16.7    15.50     15.1  118.80    11.88
# 2     NaN     NaN     NaN      NaN      NaN      NaN      NaN    4.10     4.10
# 3     NaN    16.8     9.3     12.8     10.8    13.70     15.2  180.20    15.02
# 4    9.60    12.3     4.0      5.4      NaN     3.10      5.9   95.10     8.65

# %%
data13.dtypes
# Out:
# Player       object
# Position     object
# Week 1      float64
# Week 2      float64
# Week 3      float64
# Week 4      float64
# Week 5      float64
# Week 6      float64
# Week 7      float64
# Week 8      float64
# Week 9      float64
# Week 10     float64
# Week 11     float64
# Week 12     float64
# Week 13     float64
# Totals      float64
# Average     float64
# dtype: object

# %%
data13.to_csv('/Users/bryanwenger/Desktop/Desktop_Master/Coding/github_projects/fantasy_football/Prep_Work/data_sets/wk13_data.csv')
